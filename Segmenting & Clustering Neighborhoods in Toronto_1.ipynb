# %% [markdown]
# We will be exloring, segmenting and clustering the neighborhoods in the city of Toronto based on the postal codes and borough information. For the data, we will be using the Wikipedia page which is existing and it has all the information that is needed to explore and cluster the neighborhoods in Toronto.
# We will be scrapeing this page and wrangle the data, clean it, and then read it into a pandas dataframe so that it is in a structured format.

# %% [markdown]
# Step 1:
#         Import the packages.

# %%
from bs4 import BeautifulSoup
import requests
import pandas as pd

# %% [markdown]
# Step 2:
#         Download URL data.

# %%
url = "https://en.wikipedia.org/wiki/List_of_postal_codes_of_Canada:_M"
source = requests.get(url).text
Canada_data = BeautifulSoup(source, 'lxml')

# %% [markdown]
# Step 3:
#         Creat a New Dataframe.

# %%
# Column creation of the table.
column_names = ['Postalcode','Borough','Neighborhood']
toronto = pd.DataFrame(columns = column_names)

# %%
# Content creation of the table
content = Canada_data.find('div', class_='mw-parser-output')
table = content.table.tbody
postcode = 0
borough = 0
neighborhood = 0

# %%
# Finding the required Data.
for tr in table.find_all('tr'):
    i = 0
    for td in tr.find_all('td'):
        if i == 0:
            postcode = td.text
            i = i + 1
        elif i == 1:
            borough = td.text
            i = i + 1
        elif i == 2: 
            neighborhood = td.text.strip('\n').replace(']','')
    toronto = toronto.append({'Postalcode': postcode,'Borough': borough,'Neighborhood': neighborhood},ignore_index=True)

# %% [markdown]
# Step 4:
#         Cleaning Dataframe

# %%
toronto = toronto[toronto.Borough!='Not assigned']
toronto = toronto[toronto.Borough!= 0]
toronto.reset_index(drop = True, inplace = True)
i = 0
for i in range(0,toronto.shape[0]):
    if toronto.iloc[i][2] == 'Not assigned':
        toronto.iloc[i][2] = toronto.iloc[i][1]
        i = i+1

# %%
df = toronto.groupby(['Postalcode','Borough'])['Neighborhood'].apply(', '.join).reset_index()
df.head()
# Out:
#                                           Postalcode                Borough  \
# 0                              \nM1ANot assigned\n\n  \nM2ANot assigned\n\n
# 1              \nM1BScarborough(Malvern / Rouge)\n\n  \nM2BNot assigned\n\n
# 2  \nM1CScarborough(Rouge Hill / Port Union / Hig...  \nM2CNot assigned\n\n
# 3  \nM1EScarborough(Guildwood / Morningside / Wes...  \nM2ENot assigned\n\n
# 4                       \nM1GScarborough(Woburn)\n\n  \nM2GNot assigned\n\n
#
#                                         Neighborhood
# 0                     M9AEtobicoke(Islington Avenue)
# 1  M9BEtobicoke(West Deane Park / Princess Garden...
# 2  M9CEtobicoke(Eringate / Bloordale Gardens / Ol...
# 3                                    M9ENot assigned
# 4                                    M9GNot assigned

# %% [markdown]
# Step 5:
#         Data Cleaning.

# %%
df = df.dropna()
empty = 'Not assigned'
df = df[(df.Postalcode != empty ) & (df.Borough != empty) & (df.Neighborhood != empty)]

# %%
df.head()
# Out:
#                                           Postalcode                Borough  \
# 0                              \nM1ANot assigned\n\n  \nM2ANot assigned\n\n
# 1              \nM1BScarborough(Malvern / Rouge)\n\n  \nM2BNot assigned\n\n
# 2  \nM1CScarborough(Rouge Hill / Port Union / Hig...  \nM2CNot assigned\n\n
# 3  \nM1EScarborough(Guildwood / Morningside / Wes...  \nM2ENot assigned\n\n
# 4                       \nM1GScarborough(Woburn)\n\n  \nM2GNot assigned\n\n
#
#                                         Neighborhood
# 0                     M9AEtobicoke(Islington Avenue)
# 1  M9BEtobicoke(West Deane Park / Princess Garden...
# 2  M9CEtobicoke(Eringate / Bloordale Gardens / Ol...
# 3                                    M9ENot assigned
# 4                                    M9GNot assigned

# %%
# Cleaning the table by removing "\n" from each column.
df["Postalcode"] = df["Postalcode"].str.replace("\n","")
df["Borough"] = df["Borough"].str.replace("\n","")
df["Neighborhood"] = df["Neighborhood"].str.replace("\n","")
df.head()
# Out:
#                                           Postalcode          Borough  \
# 0                                    M1ANot assigned  M2ANot assigned
# 1                    M1BScarborough(Malvern / Rouge)  M2BNot assigned
# 2  M1CScarborough(Rouge Hill / Port Union / Highl...  M2CNot assigned
# 3  M1EScarborough(Guildwood / Morningside / West ...  M2ENot assigned
# 4                             M1GScarborough(Woburn)  M2GNot assigned
#
#                                         Neighborhood
# 0                     M9AEtobicoke(Islington Avenue)
# 1  M9BEtobicoke(West Deane Park / Princess Garden...
# 2  M9CEtobicoke(Eringate / Bloordale Gardens / Ol...
# 3                                    M9ENot assigned
# 4                                    M9GNot assigned

# %%
# Listing and Grouping of Neighborhood.
def neighborhood_list(grouped):    
    return ', '.join(sorted(grouped['Neighborhood'].tolist()))
                    
grp = df.groupby(['Postalcode', 'Borough'])
df2 = grp.apply(neighborhood_list).reset_index(name='Neighborhood')

# %%
# Display the top 10 rows along with shape head
print(df2.shape)
df2.head(10)
# Out:
# (20, 3)
#                                           Postalcode  \
# 0                                    M1ANot assigned
# 1                    M1BScarborough(Malvern / Rouge)
# 2  M1CScarborough(Rouge Hill / Port Union / Highl...
# 3  M1EScarborough(Guildwood / Morningside / West ...
# 4                             M1GScarborough(Woburn)
# 5                          M1HScarborough(Cedarbrae)
# 6                M1JScarborough(Scarborough Village)
# 7  M1KScarborough(Kennedy Park / Ionview / East B...
# 8  M1LScarborough(Golden Mile / Clairlea / Oakridge)
# 9  M1MScarborough(Cliffside / Cliffcrest / Scarbo...
#
#                                          Borough  \
# 0                                M2ANot assigned
# 1                                M2BNot assigned
# 2                                M2CNot assigned
# 3                                M2ENot assigned
# 4                                M2GNot assigned
# 5               M2HNorth York(Hillcrest Village)
# ...

# %% [markdown]
# Step 6:
#        Print the Dataframe Shape.

# %%
print('The DataFrame shape is', df2.shape)
# Out:
# The DataFrame shape is (20, 3)

# %% [markdown]
# The Dataframe has 20 Postal Codes.
