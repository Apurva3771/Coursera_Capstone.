# %%
# @hidden_cell
# The project token is an authorization token that is used to access project resources like data sources, connections, and used by platform APIs.
from project_lib import Project
project = Project(project_id='2abb2edd-a885-4ebf-b001-7bcb5409b2f8', project_access_token='p-c824bc69b551cf1a52d3ce296d6af93f9e8f86f2')
pc = project.project_context

# %% [markdown]
# Before moving to the next task, let's have a quick Recap.

# %% [markdown]
# Task 1:
#         Extract data of Toronto Neighborhoods from Wikipedia, clean and display the rows along with shape head.

# %%
from bs4 import BeautifulSoup
import requests
import pandas as pd

# %%
url = "https://en.wikipedia.org/wiki/List_of_postal_codes_of_Canada:_M"
source = requests.get(url).text
Canada_data = BeautifulSoup(source, 'lxml')

# %%
# Column creation of the table.
column_names = ['Postalcode','Borough','Neighborhood']
toronto = pd.DataFrame(columns = column_names)

# %%
# Content creation of the table
content = Canada_data.find('div', class_='mw-parser-output')
table = content.table.tbody
Postalcode = 0
Borough = 0
Neighborhood = 0

# %%
# Finding the required Data.
for tr in table.find_all('tr'):
    i = 0
    for td in tr.find_all('td'):
        if i == 0:
            postcode = td.text
            i = i + 1
        elif i == 1:
            borough = td.text
            i = i + 1
        elif i == 2: 
            neighborhood = td.text.strip('\n').replace(']','')
    toronto = toronto.append({'Postalcode': postcode,'Borough': borough,'Neighborhood': neighborhood},ignore_index=True)

# %%
toronto = toronto[toronto.Borough!='Not assigned']
toronto = toronto[toronto.Borough!= 0]
toronto.reset_index(drop = True, inplace = True)
i = 0
for i in range(0,toronto.shape[0]):
    if toronto.iloc[i][2] == 'Not assigned':
        toronto.iloc[i][2] = toronto.iloc[i][1]
        i = i+1

# %%
df = toronto.groupby(['Postalcode','Borough'])['Neighborhood'].apply(', '.join).reset_index()
df.head()
# Out:
#                                           Postalcode                Borough  \
# 0                              \nM1ANot assigned\n\n  \nM2ANot assigned\n\n
# 1              \nM1BScarborough(Malvern / Rouge)\n\n  \nM2BNot assigned\n\n
# 2  \nM1CScarborough(Rouge Hill / Port Union / Hig...  \nM2CNot assigned\n\n
# 3  \nM1EScarborough(Guildwood / Morningside / Wes...  \nM2ENot assigned\n\n
# 4                       \nM1GScarborough(Woburn)\n\n  \nM2GNot assigned\n\n
#
#                                         Neighborhood
# 0                     M9AEtobicoke(Islington Avenue)
# 1  M9BEtobicoke(West Deane Park / Princess Garden...
# 2  M9CEtobicoke(Eringate / Bloordale Gardens / Ol...
# 3                                    M9ENot assigned
# 4                                    M9GNot assigned

# %%
df = df.dropna()
empty = 'Not assigned'
df = df[(df.Postalcode != empty ) & (df.Borough != empty) & (df.Neighborhood != empty)]

# %%
df.head()
# Out:
#                                           Postalcode                Borough  \
# 0                              \nM1ANot assigned\n\n  \nM2ANot assigned\n\n
# 1              \nM1BScarborough(Malvern / Rouge)\n\n  \nM2BNot assigned\n\n
# 2  \nM1CScarborough(Rouge Hill / Port Union / Hig...  \nM2CNot assigned\n\n
# 3  \nM1EScarborough(Guildwood / Morningside / Wes...  \nM2ENot assigned\n\n
# 4                       \nM1GScarborough(Woburn)\n\n  \nM2GNot assigned\n\n
#
#                                         Neighborhood
# 0                     M9AEtobicoke(Islington Avenue)
# 1  M9BEtobicoke(West Deane Park / Princess Garden...
# 2  M9CEtobicoke(Eringate / Bloordale Gardens / Ol...
# 3                                    M9ENot assigned
# 4                                    M9GNot assigned

# %%
# Cleaning the table by removing "\n" from each column.
df["Postalcode"] = df["Postalcode"].str.replace("\n","")
df["Borough"] = df["Borough"].str.replace("\n","")
df["Neighborhood"] = df["Neighborhood"].str.replace("\n","")
df.head()
# Out:
#                                           Postalcode          Borough  \
# 0                                    M1ANot assigned  M2ANot assigned
# 1                    M1BScarborough(Malvern / Rouge)  M2BNot assigned
# 2  M1CScarborough(Rouge Hill / Port Union / Highl...  M2CNot assigned
# 3  M1EScarborough(Guildwood / Morningside / West ...  M2ENot assigned
# 4                             M1GScarborough(Woburn)  M2GNot assigned
#
#                                         Neighborhood
# 0                     M9AEtobicoke(Islington Avenue)
# 1  M9BEtobicoke(West Deane Park / Princess Garden...
# 2  M9CEtobicoke(Eringate / Bloordale Gardens / Ol...
# 3                                    M9ENot assigned
# 4                                    M9GNot assigned

# %%
# Listing and Grouping of Neighborhood.
def neighborhood_list(grouped):    
    return ', '.join(sorted(grouped['Neighborhood'].tolist()))
                    
grp = df.groupby(['Postalcode', 'Borough'])
df2 = grp.apply(neighborhood_list).reset_index(name='Neighborhood')

# %%
# Display the top 10 rows along with shape head
print(df2.shape)
df2.head(10)
# Out:
# (20, 3)
#                                           Postalcode  \
# 0                                    M1ANot assigned
# 1                    M1BScarborough(Malvern / Rouge)
# 2  M1CScarborough(Rouge Hill / Port Union / Highl...
# 3  M1EScarborough(Guildwood / Morningside / West ...
# 4                             M1GScarborough(Woburn)
# 5                          M1HScarborough(Cedarbrae)
# 6                M1JScarborough(Scarborough Village)
# 7  M1KScarborough(Kennedy Park / Ionview / East B...
# 8  M1LScarborough(Golden Mile / Clairlea / Oakridge)
# 9  M1MScarborough(Cliffside / Cliffcrest / Scarbo...
#
#                                          Borough  \
# 0                                M2ANot assigned
# 1                                M2BNot assigned
# 2                                M2CNot assigned
# 3                                M2ENot assigned
# 4                                M2GNot assigned
# 5               M2HNorth York(Hillcrest Village)
# ...

# %%
print('The DataFrame shape is', df2.shape)
# Out:
# The DataFrame shape is (20, 3)

# %% [markdown]
# As per Task 2, we need to utilize the Foursuare location data, to get the latitude and the logitude coordinates of each neighborhood. For this we will be using the Geocoder Python Package.

# %% [markdown]
# Task 2:
#         Add the latitude and longitude coordinates to the dataframe.

# %% [markdown]
# Step 1:
#         For this task, we just have to use a prepared csv to retrieve the coordinates. Extract csv with Toronto geographical coordinates to dataframe.

# %%
toronto_geocsv = 'https://cocl.us/Geospatial_data'
# !wget -q -O 'toronto_m.geospatial_data.csv' toronto_geocsv
geocsv_data = pd.read_csv(toronto_geocsv).set_index("Postal Code")
geocsv_data.head()
# Out:
#               Latitude  Longitude
# Postal Code
# M1B          43.806686 -79.194353
# M1C          43.784535 -79.160497
# M1E          43.763573 -79.188711
# M1G          43.770992 -79.216917
# M1H          43.773136 -79.239476

# %% [markdown]
# Let's combine the two

# %%
df = pd.merge(geocsv_data, df2, on='Postal Code')
df.head()
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# <ipython-input-48-f45ca040eb42> in <module>
# ----> 1 df = pd.merge(geocsv_data, df2, on='Postal Code')
#       2 df.head()
#
# /opt/conda/envs/Python-3.7-main/lib/python3.7/site-packages/pandas/core/reshape/merge.py in merge(left, right, how, on, left_on, right_on, left_index, right_index, sort, suffixes, copy, indicator, validate)
#      84         copy=copy,
#      85         indicator=indicator,
# ---> 86         validate=validate,
#      87     )
#      88     return op.get_result()
#
# /opt/conda/envs/Python-3.7-main/lib/python3.7/site-packages/pandas/core/reshape/merge.py in __init__(self, left, right, how, on, left_on, right_on, axis, left_index, right_index, sort, suffixes, copy, indicator, validate)
#     625             self.right_join_keys,
#     626             self.join_names,
# ...

# %%
df = df[['Postal Code', 'Borough', 'Neighborhood', 'Latitude', 'Longitude']]
df.head(11)
# Out:
# Empty DataFrame
# Columns: [Postal Code, Borough, Neighborhood, Latitude, Longitude]
# Index: []

# %%
df.to_csv('Toronto.TASK_II_df.csv',index=False)

# %%
df.shape
# Out:
# (0, 5)
